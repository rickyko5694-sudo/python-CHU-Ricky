# %% [markdown]
# <a href="https://colab.research.google.com/github/rickyko5694-sudo/python-CHU-Ricky/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# P01-01 Hello

# %%
print("Hello,Python! I am Ricky.Nice to meet you,2026")
# Out:
# Hello,Python! I am Ricky.Nice to meet you,2026

# %% [markdown]
# P01-02 My Name

# %%
name="CHU,Hsinchu,Taiwan"
print(name)
# Out:
# CHU,Hsinchu,Taiwan

# %% [markdown]
# P01-03 Self Intro

# %%
name="Ricky"
print("I am" + name)
# Out:
# I amRicky

# %% [markdown]
# P01-04 Basic Math

# %%
print(10+5)
# Out:
# 15

# %% [markdown]
# P01-05 Mulit-print

# %%
print(1,2,3)
# Out:
# 1 2 3

# %% [markdown]
# P01-06 Separator

# %%
print("2023","01","01",sep="-")
# Out:
# 2023-01-01

# %% [markdown]
# P01-07 End param

# %%
print("Hello",end=" ")
print("World")
# Out:
# Hello World

# %% [markdown]
# P01-08 Variablrs Swap(Temp)

# %%
a=1
b=2
temp=a
a=b
b=temp
print(a,b)
# Out:
# 2 1

# %% [markdown]
# P01-09 Python Swap

# %%
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %% [markdown]
# P01-10 Input

# %%
name=input("Name?")
print(f"Hi,{name}")
# Out:
# Name?RICKY
# Hi,RICKY

# %% [markdown]
# P01-11 Input Int

# %%
age_str=input("Age?")
age= int(age_str)
print(age)
# Out:
# Age?20
# 20
