# %% [markdown]
# <a href="https://colab.research.google.com/github/rickyko5694-sudo/python-CHU-Ricky/blob/main/week_6_unit_5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# P06-01 Create Dict

# %%
student = {"name":"Ricky","age":20,"major":"IM"}
print(student)
# Out:
# {'name': 'Ricky', 'age': 20, 'major': 'IM'}

# %% [markdown]
# P06-02 Access by Key

# %%
print(student["name"])
# Out:
# Ricky

# %% [markdown]
# P06-03 Update/Add

# %%
student["age"] = 20
student["gpa"] = 3.8

# %% [markdown]
# P06-04 Del

# %%
del student["major"]

# %% [markdown]
# P06-05 to P06-07 Keys/Values/Items

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age', 'gpa'])
# dict_values(['Ricky', 20, 3.8])
# dict_items([('name', 'Ricky'), ('age', 20), ('gpa', 3.8)])

# %% [markdown]
# P06-08 Get Method

# %%
print(student.get("phone","Not Found"))
# Out:
# Not Found

# %% [markdown]
# P06-09 Check Key

# %%
if "name" in student:
  print("Fount")
# Out:
# Fount

# %% [markdown]
# P06-10 Nested

# %%
data = {
    "name":"Tom",
    "scores":[100, 90, 80]
}
print(data["scores"][0])
# Out:
# 100

# %% [markdown]
# P06-11 Create Set

# %%
s = {1, 2, 3, 3, 2}
print(s)
# Out:
# {1, 2, 3}

# %% [markdown]
# P06-12 to P06-13 Add/Remove

# %%
s.add(4)
s.remove(1)

# %% [markdown]
# P06-14 Set Unique

# %%
nums = [1, 2, 2, 3, 3, 3]
unique_nums = list(set(nums))
print(unique_nums)
# Out:
# [1, 2, 3]

# %% [markdown]
# P06-15 to P06-17 Set Operations

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a | b)
print(a & b)
print(a - b)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %% [markdown]
# P06-18 Dict Loop

# %%
for k, v in student.items():
  print(f"{k}:{v}")
# Out:
# name:Ricky
# age:20
# gpa:3.8
